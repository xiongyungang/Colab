# %% [markdown]
# <a href="https://colab.research.google.com/github/xiongyungang/Colab/blob/main/sincos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# 设置中文字体（避免乱码），兼容 Windows/macOS/Linux
plt.rcParams['font.sans-serif'] = ['SimHei', 'Arial Unicode MS', 'DejaVu Sans', 'sans-serif']
plt.rcParams['axes.unicode_minus'] = False  # 正常显示负号

# 生成数据
x = np.linspace(0, 2 * np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)

# 绘图
plt.figure(figsize=(8, 5))
plt.plot(x, y_sin, label='sin(x)', color='blue', linewidth=2)
plt.plot(x, y_cos, label='cos(x)', color='red', linewidth=2, linestyle='--')

# 添加标题与标签
plt.title('sin & cos', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.grid(True, alpha=0.3)
plt.legend()

# 显示图表
plt.tight_layout()
plt.show()

# %% [markdown]
# # 新段落
